# %% [markdown]
# ## slicing list

# %%
my_list = [1,2,3,4,5]
my_list [2:]
# Out:
# [3, 4, 5]

# %%
my_list = [1,2,3,4,5]
my_list [::2]
# Out:
# [1, 3, 5]

# %%
my_list = list(range(100))
my_list [::-10]
# Out:
# [99, 89, 79, 69, 59, 49, 39, 29, 19, 9]

# %%
# this above problem is called stepping methode of stepping into list.

# %% [markdown]
# ## modifying list

# %%
my_list = [1,2,3,4]
my_list.append(5)
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# this above append feature is used to append means increase values or add values

# %%
my_list.insert(3, 'a new value')
print(my_list)
# Out:
# [1, 2, 3, 'a new value', 4, 5]

# %%
# this above insert fature is used to inster any value at any postion of place in the list

# %%
my_list.remove('a new value')
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# above feature is remove which is used to remove any component of the list just name it

# %%
my_list.pop()
# Out:
# 5

# %%
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
# this above feature is also used for removeing items but is just remove the last item without any arguement

# %%
while len(my_list):
    print(my_list.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
print(my_list)
# Out:
# []

# %% [markdown]
# ## sets

# %%
my_set = {1,2,3}
print(my_set)
# Out:
# {1, 2, 3}

# %%
my_list = [1,2,2,3,3,4,4]
my_list = list(set(my_list))
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_set.add(5)
print(my_set)
# Out:
# {1, 2, 3, 5}

# %%
# in sets for adding we use add instead of append

# %%
len(my_set)
# Out:
# 4

# %%
while len(my_set):
    print(my_set.pop())
# Out:
# 1
# 2
# 3
# 5

# %%
my_set = {1,2,3}
my_set.discard(3)
print(my_set)
# Out:
# {1, 2}

# %%
# discard is used to remove any specific items in sets as i learned

# %% [markdown]
# ## tuples

# %%
my_tuples = (1,2,3,4)
print(my_tuples)
# Out:
# (1, 2, 3, 4)

# %%
my_tuples[0]
# Out:
# 1

# %%
# why should we use tuples if we can not modify them ?

# %%
''' because tuples :
- more efficient then list 
- they dont grow or change 
- stores compactly in memory 
- and the best feature that they are used by default in python as we can see in the next example below 
'''
# Out:
# ' because tuples :\n- more efficient then list \n- they dont grow or change \n- stores compactly in memory \n- and the best feature that they are used by default in python as we can see in the next example below \n'

# %%
def pythondefault():
    return 1,2,3

type(pythondefault())
# Out:
# tuple

# %%
my_tuple = (1,2,3)
type(my_tuple)
# Out:
# tuple

# %%
a, b, c = pythondefault()
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
#this is called unpcaking values

# %% [markdown]
# ## dictionaries

# %%
animals = {
    'a' : 'dog' ,
    'b' : 'cat' ,
    'c' : 'mee' ,
   
}
animals
# Out:
# {'a': 'dog', 'b': 'cat', 'c': 'mee'}

# %%
animals['a']
# Out:
# 'dog'

# %%
animals['d'] = 'mouse'

# %%
animals
# Out:
# {'a': 'dog', 'b': 'cat', 'c': 'mee', 'd': 'mouse'}

# %%
animals['a'] = 'manydog'
animals
# Out:
# {'a': 'manydog', 'b': 'cat', 'c': 'mee', 'd': 'mouse'}

# %%
animals.keys()
#tells what are the keys in the dictionaries
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
animals.values()
#tells what are the values of the keys in the dictionaries
# Out:
# dict_values(['manydog', 'cat', 'mee', 'mouse'])

# %%
#just below i learned how to convert dictionaries into list

# %%
list(animals.keys())
# Out:
# ['a', 'b', 'c', 'd']

# %%
#if we try to get a value thats not there it will show error just like this 
animals['e']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 #if we try to get a value thats not there it will show error just like this
# ----> 2 animals['e']
#
# KeyError: 'e'

# %%
#and for that we can do something like this

# %%
animals.get('e', 'elephant')
# Out:
# 'elephant'

# %%
#or 
print(animals.get('e'))
# Out:
# None

# %%
len(animals)
# Out:
# 4

# %%
animals = {
    'a' : ['dog', 'manydog'] ,
    'b' : ['cat'] ,
    'c' : ['mee'] ,
    'd' : ['dino'] ,
}

# %%
animals['d'].append('dinasour')

# %%
animals
# Out:
# {'a': ['dog', 'manydog'],
#  'b': ['cat'],
#  'c': ['mee'],
#  'd': ['dino', 'dinasour']}

# %%
#now we are trying to modify our dic but we dont know if that feature is in it or not so we dont overwrote it ...

# %%
animals['e'] = ['elephant']

# %%
if 'e' not in animals:
    animals['e'] = []

animals['e'].append('elephant')
