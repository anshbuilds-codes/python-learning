# %% [markdown]
# ## contol flow

# %% [markdown]
# # if

# %%
a = True
if a:
    print('a is True')
    print('might be True')
print('a is false')
# Out:
# a is True
# might be True
# a is false

# %%
a = False
if a:
    print('a is true')
    print('might be ture')
print('for sure a is false')
# Out:
# for sure a is false

# %% [markdown]
# # else

# %%
a = True
if a:
    print('a is True')
    print('might be True')
else:
    print('a is false')
print('a is false')
# Out:
# a is True
# might be True
# a is false

# %%
a = False
if a:
    print('a is True')
    print('might be True')
else:
    print('a is false')
print('a is false')
# Out:
# a is false
# a is false

# %% [markdown]
# # indenting

# %%
a = True 
b = True 
c = True 
if a:
    print('a is true')
else:
    ('a is false and because of a b and c are also false, indent')
    if b:
        print('b is also true')
    else:
        ('b is false therefore c is also false because it is and indent of c')
        if c:
            print('for sure c is ture')
        else:
            ('only c is false')
# Out:
# a is true

# %%
a = True 
b = True 
c = True 
if a:
    print('a is true')
    if b:
        print('b is also true')
    else:
        ('b is false therefore c is also false because it is and indent of c')
        if c:
            print('for sure c is ture')
        else:
            ('only c is false')
# Out:
# a is true
# b is also true

# %%
a = True 
b = True 
c = False 
if a:
    print('a is true')
    if b:
        print('b is also true')
        if c:
            print('for sure c is ture')
        else:
            print('only c is false')
# Out:
# a is true
# b is also true
# only c is false

# %% [markdown]
# # absolute last if else

# %%
a = True 
b = True 
c = True 
if a:
    print('a is true')
else:
    ('a is false ')
if b:
    print('b is also true')
else:
    ('b is false ')
if c:
    print('for sure c is ture')
else:
    ('c is false')
# Out:
# a is true
# b is also true
# for sure c is ture

# %%
a = True 
b = False
c = True 
if a:
    print('a is true')
else:
    ('a is false ')
if b:
    print('b is also true')
else:
    ('b is false ')
if c:
    print('for sure c is ture')
else:
    ('c is false')
# Out:
# a is true
# for sure c is ture

# %%
a = False
b = False
c = True 
if a:
    print('a is true')
else:
    ('a is false ')
if b:
    print('b is also true')
else:
    ('b is false ')
if c:
    print('for sure c is ture')
else:
    ('c is false')
# Out:
# for sure c is ture

# %% [markdown]
# ## for loops

# %%
a = [1,2,3,4,5]
for num in a:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
5 in a
# Out:
# True

# %%
6 in a
# Out:
# False

# %% [markdown]
# ## while loops

# %%
a = 0
while a < 5:
    print(a)
    a = a + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## functions

# %%
print("hello world")
# Out:
# hello world

# %%
def threetimes(val):
    return 3 * val
threetimes(4)
# Out:
# 12

# %%
def multiply(val1, val2):
    return val1 * val2
multiply(3, 4)
# Out:
# 12

# %% [markdown]
# ## classes

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.age = '18'

    def introduce(self):
        print("my name is", self.name)

# %%
my_Student = Student('Shaurya')
another_Student = Student('ansh')

# %%
my_Student.introduce()
# Out:
# my name is Shaurya
