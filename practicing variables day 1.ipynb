# %% [markdown]
# ## variable
# # in python

# %%
x = 5
print(x)
# Out:
# 5

# %%
x
# Out:
# 5

# %% [markdown]
# ## string

# %%
name = 'shaurya'
print(name)
# Out:
# shaurya

# %%
'1' + '1'
# Out:
# '11'

# %%
'string 1' + 'string 2'
# Out:
# 'string 1string 2'

# %%
type(1.456789)
# Out:
# float

# %% [markdown]
# ## data structures

# %% [markdown]
# # list

# %%
my_list = [1,2,3,4,5,6] 
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_list = [[1,2,3], [False, True], []]
len(my_list)
# Out:
# 3

# %%
len(my_list)
# Out:
# 6

# %% [markdown]
# # tuples

# %%
my_tuples = [1,2,3,]
len(my_tuples)
# Out:
# 3

# %%
# tuples can not be chnaged neither added later , they are memory efficient

# %% [markdown]
# # dictionaries

# %%
my_dictionary = {
    'apple' : 'a red fruit',
    'orange' : 'good in vitamins'
}
my_dictionary['apple']
# Out:
# 'a red fruit'

# %% [markdown]
# # sets

# %%
my_set = {1,3,2,2}

# %%
len(my_set)
# Out:
# 2

# %%
len(my_set)
# Out:
# 3

# %% [markdown]
# ## operators

# %%
1 + 1
# Out:
# 2

# %%
2 * 3
# Out:
# 6

# %%
5 ** 2
# Out:
# 25

# %%
6 / 4
# Out:
# 1.5

# %%
20 / 6
# Out:
# 3.3333333333333335

# %%
20 / 5
# Out:
# 4.0

# %%
20 % 6
# Out:
# 2

# %%
1 == 1
# Out:
# True

# %%
1 >= 2
# Out:
# False

# %%
7 >= 8
# Out:
# False

# %%
7 <= 8
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False and True
# Out:
# False

# %%
not True
# Out:
# False
